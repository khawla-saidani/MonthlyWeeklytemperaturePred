# %% [markdown]
# # Example Prediction Temperature Working on 11th Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Month11.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1209, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.179323 -0.463112  1.481681 -0.191191 -0.616172 -1.527159 -17.426381
# 1  -0.000677  1.396888  2.181681 -0.151191  1.793828  0.372841  -8.116381
# 2  -0.070677  2.376889  1.841681 -0.111191  3.063828  0.552841  -4.486381
# 3  -0.060677  1.176889  2.421681  0.048809  1.383828  1.402841   0.263619
# 4  -0.030677 -0.803111  2.751681  0.468809 -1.126172  1.892841   2.643619

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (967, 7), jeu d'évaluation : (242, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s
100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.1351 - val_loss: nan
# Epoch 73/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.0820 - val_loss: nan
# Epoch 74/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.0299 - val_loss: nan
# Epoch 75/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.9788 - val_loss: nan
# Epoch 76/100
# 4/4 [==============================] - 0s 107ms/step - loss: 1.9290 - val_loss: nan
# Epoch 77/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.8803 - val_loss: nan
# Epoch 78/100
# 4/4 [==============================] - 0s 95ms/step - loss: 1.8328 - val_loss: nan
# Epoch 79/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.7867 - val_loss: nan
# Epoch 80/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.7417 - val_loss: nan
# Epoch 81/100
# 4/4 [==============================] - 0s 101ms/step - loss: 1.6978 - val_loss: nan
# Epoch 82/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.6548 - val_loss: nan
# Epoch 83/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.6128 - val_loss: nan
# Epoch 84/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.5718 - val_loss: nan
# Epoch 85/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.5318 - val_loss: nan
# Epoch 86/100
# 4/4 [==============================] - 0s 96ms/step - loss: 1.4931 - val_loss: nan
# Epoch 87/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.4555 - val_loss: nan
# Epoch 88/100
# 4/4 [==============================] - 0s 103ms/step - loss: 1.4189 - val_loss: nan
# Epoch 89/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.3833 - val_loss: nan
# Epoch 90/100
# 4/4 [==============================] - 0s 106ms/step - loss: 1.3488 - val_loss: nan
# Epoch 91/100
# 4/4 [==============================] - 0s 107ms/step - loss: 1.3152 - val_loss: nan
# Epoch 92/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.2825 - val_loss: nan
# Epoch 93/100
# 4/4 [==============================] - 0s 102ms/step - loss: 1.2506 - val_loss: nan
# Epoch 94/100
# 4/4 [==============================] - 0s 117ms/step - loss: 1.2196 - val_loss: nan
# Epoch 95/100
# 4/4 [==============================] - 0s 105ms/step - loss: 1.1894 - val_loss: nan
# Epoch 96/100
# 4/4 [==============================] - 0s 109ms/step - loss: 1.1600 - val_loss: nan
# Epoch 97/100
# 4/4 [==============================] - 0s 115ms/step - loss: 1.1314 - val_loss: nan
# Epoch 98/100
# 4/4 [==============================] - 1s 114ms/step - loss: 1.1036 - val_loss: nan
# Epoch 99/100
# 4/4 [==============================] - 0s 119ms/step - loss: 1.0765 - val_loss: nan
# Epoch 100/100
# 4/4 [==============================] - 0s 100ms/step - loss: 1.0501 - val_loss: nan

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 16ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : nan

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 4s 467ms/step - loss: 14.7401 - val_loss: 0.1593
# Epoch 2/50
# 4/4 [==============================] - 1s 128ms/step - loss: 12.9371 - val_loss: 0.4032
# Epoch 3/50
# 4/4 [==============================] - 1s 147ms/step - loss: 11.3493 - val_loss: 0.7820
# Epoch 4/50
# 4/4 [==============================] - 1s 162ms/step - loss: 9.9499 - val_loss: 1.2812
# Epoch 5/50
# 4/4 [==============================] - 1s 145ms/step - loss: 8.7219 - val_loss: 1.9221
# Epoch 6/50
# 4/4 [==============================] - 1s 129ms/step - loss: 7.6713 - val_loss: 2.6221
# Epoch 7/50
# 4/4 [==============================] - 1s 120ms/step - loss: 6.8251 - val_loss: 3.3120
# Epoch 8/50
# 4/4 [==============================] - 1s 140ms/step - loss: 6.2095 - val_loss: 3.8646
# Epoch 9/50
# 4/4 [==============================] - 1s 120ms/step - loss: 5.8165 - val_loss: 4.1104
# Epoch 10/50
# 4/4 [==============================] - 1s 130ms/step - loss: 5.6000 - val_loss: 3.9400
# Epoch 11/50
# 4/4 [==============================] - 1s 124ms/step - loss: 5.4676 - val_loss: 3.4094
# Epoch 12/50
# 4/4 [==============================] - 1s 124ms/step - loss: 5.3475 - val_loss: 2.7140
# Epoch 13/50
# 4/4 [==============================] - 1s 150ms/step - loss: 5.2219 - val_loss: 2.0468
# Epoch 14/50
# 4/4 [==============================] - 1s 158ms/step - loss: 5.1077 - val_loss: 1.5126
# Epoch 15/50
# 4/4 [==============================] - 1s 145ms/step - loss: 5.0202 - val_loss: 1.1388
# Epoch 16/50
# 4/4 [==============================] - 1s 159ms/step - loss: 4.9561 - val_loss: 0.9016
# Epoch 17/50
# 4/4 [==============================] - 1s 115ms/step - loss: 4.9024 - val_loss: 0.7694
# Epoch 18/50
# 4/4 [==============================] - 0s 116ms/step - loss: 4.8516 - val_loss: 0.7046
# Epoch 19/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.8032 - val_loss: 0.6761
# Epoch 20/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.7602 - val_loss: 0.6594
# Epoch 21/50
# 4/4 [==============================] - 1s 144ms/step - loss: 4.7235 - val_loss: 0.6367
# Epoch 22/50
# 4/4 [==============================] - 0s 119ms/step - loss: 4.6921 - val_loss: 0.5989
# Epoch 23/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.6639 - val_loss: 0.5471
# Epoch 24/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.6378 - val_loss: 0.4914
# Epoch 25/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.6133 - val_loss: 0.4439
# Epoch 26/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.5901 - val_loss: 0.4107
# Epoch 27/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.5678 - val_loss: 0.3952
# Epoch 28/50
# 4/4 [==============================] - 1s 116ms/step - loss: 4.5464 - val_loss: 0.3927
# Epoch 29/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.5253 - val_loss: 0.3981
# Epoch 30/50
# 4/4 [==============================] - 0s 116ms/step - loss: 4.5048 - val_loss: 0.4068
# Epoch 31/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.4850 - val_loss: 0.4147
# Epoch 32/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.4658 - val_loss: 0.4209
# Epoch 33/50
# 4/4 [==============================] - 0s 115ms/step - loss: 4.4472 - val_loss: 0.4270
# Epoch 34/50
# 4/4 [==============================] - 0s 123ms/step - loss: 4.4294 - val_loss: 0.4340
# Epoch 35/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.4121 - val_loss: 0.4442
# Epoch 36/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.3954 - val_loss: 0.4575
# Epoch 37/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.3791 - val_loss: 0.4733
# Epoch 38/50
# 4/4 [==============================] - 1s 137ms/step - loss: 4.3631 - val_loss: 0.4892
# Epoch 39/50
# 4/4 [==============================] - 0s 119ms/step - loss: 4.3475 - val_loss: 0.5044
# Epoch 40/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.3321 - val_loss: 0.5180
# Epoch 41/50
# 4/4 [==============================] - 1s 139ms/step - loss: 4.3169 - val_loss: 0.5309
# Epoch 42/50
# 4/4 [==============================] - 1s 144ms/step - loss: 4.3020 - val_loss: 0.5433
# Epoch 43/50
# 4/4 [==============================] - 1s 133ms/step - loss: 4.2874 - val_loss: 0.5576
# Epoch 44/50
# 4/4 [==============================] - 1s 129ms/step - loss: 4.2731 - val_loss: 0.5739
# Epoch 45/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.2591 - val_loss: 0.5913
# Epoch 46/50
# 4/4 [==============================] - 0s 115ms/step - loss: 4.2453 - val_loss: 0.6082
# Epoch 47/50
# 4/4 [==============================] - 1s 127ms/step - loss: 4.2319 - val_loss: 0.6245
# Epoch 48/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.2186 - val_loss: 0.6380
# Epoch 49/50
# 4/4 [==============================] - 1s 127ms/step - loss: 4.2057 - val_loss: 0.6487
# Epoch 50/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.1933 - val_loss: 0.6600

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")
# Out:
# 1/1 [==============================] - 0s 442ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

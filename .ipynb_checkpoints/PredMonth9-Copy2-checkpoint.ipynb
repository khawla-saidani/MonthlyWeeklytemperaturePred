# %% [markdown]
# # Example Prediction Temperature Working on 10th Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Month10.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1209, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.069323  1.016889 -5.018319  0.368809  1.403828 -1.647159   6.143619
# 1   0.069323  1.526889 -4.468319  0.368809  1.883828  1.402841  20.143619
# 2  -0.060677  0.756888 -6.958319  0.338809  0.693828  1.832841  27.073619
# 3   0.029323  0.596889 -6.708319  0.358809  0.523828  0.242841  16.383619
# 4   0.049323 -1.063111 -8.228319  0.768809 -1.566172  1.532841  27.383619

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (967, 7), jeu d'évaluation : (242, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s
100
# 4/4 [==============================] - 0s 99ms/step - loss: 3.7918 - val_loss: 4.2173
# Epoch 67/100
# 4/4 [==============================] - 0s 125ms/step - loss: 3.7227 - val_loss: 4.1685
# Epoch 68/100
# 4/4 [==============================] - 0s 123ms/step - loss: 3.6575 - val_loss: 4.1241
# Epoch 69/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.5956 - val_loss: 4.0846
# Epoch 70/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.5368 - val_loss: 4.0540
# Epoch 71/100
# 4/4 [==============================] - 1s 107ms/step - loss: 3.4821 - val_loss: 4.0314
# Epoch 72/100
# 4/4 [==============================] - 0s 116ms/step - loss: 3.4314 - val_loss: 4.0099
# Epoch 73/100
# 4/4 [==============================] - 0s 102ms/step - loss: 3.3843 - val_loss: 3.9858
# Epoch 74/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.3403 - val_loss: 3.9621
# Epoch 75/100
# 4/4 [==============================] - 0s 97ms/step - loss: 3.2990 - val_loss: 3.9393
# Epoch 76/100
# 4/4 [==============================] - 0s 96ms/step - loss: 3.2599 - val_loss: 3.9166
# Epoch 77/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.2225 - val_loss: 3.8926
# Epoch 78/100
# 4/4 [==============================] - 0s 119ms/step - loss: 3.1860 - val_loss: 3.8660
# Epoch 79/100
# 4/4 [==============================] - 0s 116ms/step - loss: 3.1498 - val_loss: 3.8366
# Epoch 80/100
# 4/4 [==============================] - 1s 132ms/step - loss: 3.1135 - val_loss: 3.8042
# Epoch 81/100
# 4/4 [==============================] - 0s 106ms/step - loss: 3.0769 - val_loss: 3.7707
# Epoch 82/100
# 4/4 [==============================] - 0s 110ms/step - loss: 3.0402 - val_loss: 3.7357
# Epoch 83/100
# 4/4 [==============================] - 0s 102ms/step - loss: 3.0031 - val_loss: 3.6983
# Epoch 84/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.9657 - val_loss: 3.6583
# Epoch 85/100
# 4/4 [==============================] - 0s 93ms/step - loss: 2.9280 - val_loss: 3.6171
# Epoch 86/100
# 4/4 [==============================] - 0s 98ms/step - loss: 2.8898 - val_loss: 3.5758
# Epoch 87/100
# 4/4 [==============================] - 0s 98ms/step - loss: 2.8512 - val_loss: 3.5344
# Epoch 88/100
# 4/4 [==============================] - 0s 94ms/step - loss: 2.8124 - val_loss: 3.4918
# Epoch 89/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.7734 - val_loss: 3.4475
# Epoch 90/100
# 4/4 [==============================] - 0s 94ms/step - loss: 2.7340 - val_loss: 3.4019
# Epoch 91/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.6942 - val_loss: 3.3554
# Epoch 92/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.6539 - val_loss: 3.3080
# Epoch 93/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.6132 - val_loss: 3.2597
# Epoch 94/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.5722 - val_loss: 3.2106
# Epoch 95/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.5310 - val_loss: 3.1610
# Epoch 96/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.4894 - val_loss: 3.1108
# Epoch 97/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.4476 - val_loss: 3.0604
# Epoch 98/100
# 4/4 [==============================] - 0s 96ms/step - loss: 2.4058 - val_loss: 3.0097
# Epoch 99/100
# 4/4 [==============================] - 0s 98ms/step - loss: 2.3638 - val_loss: 2.9586
# Epoch 100/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.3219 - val_loss: 2.9075

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 10ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : nan

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 4s 368ms/step - loss: 57.1961 - val_loss: 47.8478
# Epoch 2/50
# 4/4 [==============================] - 1s 122ms/step - loss: 51.8574 - val_loss: 43.8277
# Epoch 3/50
# 4/4 [==============================] - 1s 136ms/step - loss: 47.0653 - val_loss: 39.8031
# Epoch 4/50
# 4/4 [==============================] - 1s 125ms/step - loss: 42.7099 - val_loss: 36.3631
# Epoch 5/50
# 4/4 [==============================] - 1s 123ms/step - loss: 38.6812 - val_loss: 33.1310
# Epoch 6/50
# 4/4 [==============================] - 1s 124ms/step - loss: 34.8404 - val_loss: 29.7791
# Epoch 7/50
# 4/4 [==============================] - 1s 123ms/step - loss: 31.0298 - val_loss: 26.0710
# Epoch 8/50
# 4/4 [==============================] - 1s 126ms/step - loss: 27.1797 - val_loss: 22.1438
# Epoch 9/50
# 4/4 [==============================] - 1s 122ms/step - loss: 23.3162 - val_loss: 18.1905
# Epoch 10/50
# 4/4 [==============================] - 1s 133ms/step - loss: 19.5406 - val_loss: 14.4318
# Epoch 11/50
# 4/4 [==============================] - 1s 138ms/step - loss: 15.9734 - val_loss: 10.9973
# Epoch 12/50
# 4/4 [==============================] - 1s 134ms/step - loss: 12.7519 - val_loss: 7.9990
# Epoch 13/50
# 4/4 [==============================] - 1s 137ms/step - loss: 9.9993 - val_loss: 5.5162
# Epoch 14/50
# 4/4 [==============================] - 0s 119ms/step - loss: 7.8044 - val_loss: 3.5502
# Epoch 15/50
# 4/4 [==============================] - 0s 118ms/step - loss: 6.2122 - val_loss: 2.0992
# Epoch 16/50
# 4/4 [==============================] - 1s 118ms/step - loss: 5.1973 - val_loss: 1.1232
# Epoch 17/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.6615 - val_loss: 0.5399
# Epoch 18/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.4659 - val_loss: 0.2380
# Epoch 19/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.4628 - val_loss: 0.1053
# Epoch 20/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.5284 - val_loss: 0.0563
# Epoch 21/50
# 4/4 [==============================] - 0s 122ms/step - loss: 4.5833 - val_loss: 0.0419
# Epoch 22/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.5954 - val_loss: 0.0435
# Epoch 23/50
# 4/4 [==============================] - 0s 121ms/step - loss: 4.5669 - val_loss: 0.0588
# Epoch 24/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.5159 - val_loss: 0.0893
# Epoch 25/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.4607 - val_loss: 0.1331
# Epoch 26/50
# 4/4 [==============================] - 0s 121ms/step - loss: 4.4126 - val_loss: 0.1833
# Epoch 27/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.3756 - val_loss: 0.2312
# Epoch 28/50
# 4/4 [==============================] - 1s 119ms/step - loss: 4.3483 - val_loss: 0.2693
# Epoch 29/50
# 4/4 [==============================] - 0s 120ms/step - loss: 4.3275 - val_loss: 0.2934
# Epoch 30/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.3104 - val_loss: 0.3031
# Epoch 31/50
# 4/4 [==============================] - 0s 119ms/step - loss: 4.2951 - val_loss: 0.3007
# Epoch 32/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.2806 - val_loss: 0.2898
# Epoch 33/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.2664 - val_loss: 0.2742
# Epoch 34/50
# 4/4 [==============================] - 0s 119ms/step - loss: 4.2524 - val_loss: 0.2572
# Epoch 35/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.2382 - val_loss: 0.2409
# Epoch 36/50
# 4/4 [==============================] - 0s 120ms/step - loss: 4.2232 - val_loss: 0.2268
# Epoch 37/50
# 4/4 [==============================] - 0s 123ms/step - loss: 4.2073 - val_loss: 0.2150
# Epoch 38/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.1901 - val_loss: 0.2053
# Epoch 39/50
# 4/4 [==============================] - 1s 133ms/step - loss: 4.1713 - val_loss: 0.1975
# Epoch 40/50
# 4/4 [==============================] - 1s 134ms/step - loss: 4.1513 - val_loss: 0.1918
# Epoch 41/50
# 4/4 [==============================] - 1s 133ms/step - loss: 4.1304 - val_loss: 0.1861
# Epoch 42/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.1093 - val_loss: 0.1797
# Epoch 43/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.0882 - val_loss: 0.1724
# Epoch 44/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.0676 - val_loss: 0.1639
# Epoch 45/50
# 4/4 [==============================] - 0s 123ms/step - loss: 4.0477 - val_loss: 0.1542
# Epoch 46/50
# 4/4 [==============================] - 1s 138ms/step - loss: 4.0288 - val_loss: 0.1440
# Epoch 47/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.0108 - val_loss: 0.1335
# Epoch 48/50
# 4/4 [==============================] - 0s 116ms/step - loss: 3.9936 - val_loss: 0.1235
# Epoch 49/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.9771 - val_loss: 0.1141
# Epoch 50/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.9612 - val_loss: 0.1059

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")
# Out:
# 1/1 [==============================] - 0s 457ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

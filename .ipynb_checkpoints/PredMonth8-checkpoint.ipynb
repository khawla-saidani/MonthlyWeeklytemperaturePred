# %% [markdown]
# # Example Prediction Temperature Working on 7th Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Month7.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1209, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.009323  0.376889 -6.338319 -0.211191  0.483828 -2.197159   5.323619
# 1  -0.070677  1.336888 -5.818319 -0.281191  1.533828 -0.607159  10.703619
# 2  -0.050677  1.286889 -7.238319 -0.011191  1.653828  0.182841  17.143619
# 3   0.029323 -0.123111 -5.878319  0.048809 -0.096172 -2.617159   1.013619
# 4   0.039323 -0.753112 -4.898319  0.038809 -0.826172 -1.887159   1.703619

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (967, 7), jeu d'évaluation : (242, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 313ms/step - loss: 78.0357 - val_loss: 100.6579
# Epoch 2/100
# 4/4 [==============================] - 0s 95ms/step - loss: 77.2746 - val_loss: 99.8023
# Epoch 3/100
# 4/4 [==============================] - 0s 101ms/step - loss: 76.5163 - val_loss: 98.9212
# Epoch 4/100
# 4/4 [==============================] - 0s 100ms/step - loss: 75.7537 - val_loss: 98.0099
# Epoch 5/100
# 4/4 [==============================] - 0s 100ms/step - loss: 74.9793 - val_loss: 97.0614
# 4/4 [==============================] - 1s 133ms/step - loss: 8.4249 - val_loss: 14.8028
# Epoch 68/100
# 4/4 [==============================] - 0s 122ms/step - loss: 7.9624 - val_loss: 14.1086
# Epoch 69/100
# 4/4 [==============================] - 0s 100ms/step - loss: 7.5349 - val_loss: 13.4643
# Epoch 70/100
# 4/4 [==============================] - 0s 100ms/step - loss: 7.1420 - val_loss: 12.8674
# Epoch 71/100
# 4/4 [==============================] - 0s 99ms/step - loss: 6.7835 - val_loss: 12.3151
# Epoch 72/100
# 4/4 [==============================] - 0s 100ms/step - loss: 6.4585 - val_loss: 11.8041
# Epoch 73/100
# 4/4 [==============================] - 0s 100ms/step - loss: 6.1658 - val_loss: 11.3316
# Epoch 74/100
# 4/4 [==============================] - 0s 100ms/step - loss: 5.9034 - val_loss: 10.8945
# Epoch 75/100
# 4/4 [==============================] - 0s 100ms/step - loss: 5.6688 - val_loss: 10.4903
# Epoch 76/100
# 4/4 [==============================] - 0s 100ms/step - loss: 5.4595 - val_loss: 10.1166
# Epoch 77/100
# 4/4 [==============================] - 0s 100ms/step - loss: 5.2731 - val_loss: 9.7712
# Epoch 78/100
# 4/4 [==============================] - 0s 105ms/step - loss: 5.1073 - val_loss: 9.4520
# Epoch 79/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.9601 - val_loss: 9.1573
# Epoch 80/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.8294 - val_loss: 8.8853
# Epoch 81/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.7135 - val_loss: 8.6343
# Epoch 82/100
# 4/4 [==============================] - 0s 95ms/step - loss: 4.6110 - val_loss: 8.4029
# Epoch 83/100
# 4/4 [==============================] - 0s 94ms/step - loss: 4.5202 - val_loss: 8.1895
# Epoch 84/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.4400 - val_loss: 7.9929
# Epoch 85/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.3690 - val_loss: 7.8118
# Epoch 86/100
# 4/4 [==============================] - 0s 99ms/step - loss: 4.3063 - val_loss: 7.6450
# Epoch 87/100
# 4/4 [==============================] - 0s 95ms/step - loss: 4.2509 - val_loss: 7.4913
# Epoch 88/100
# 4/4 [==============================] - 0s 111ms/step - loss: 4.2017 - val_loss: 7.3497
# Epoch 89/100
# 4/4 [==============================] - 0s 127ms/step - loss: 4.1582 - val_loss: 7.2192
# Epoch 90/100
# 4/4 [==============================] - 0s 117ms/step - loss: 4.1194 - val_loss: 7.0989
# Epoch 91/100
# 4/4 [==============================] - 0s 95ms/step - loss: 4.0848 - val_loss: 6.9879
# Epoch 92/100
# 4/4 [==============================] - 0s 100ms/step - loss: 4.0538 - val_loss: 6.8854
# Epoch 93/100
# 4/4 [==============================] - 0s 99ms/step - loss: 4.0259 - val_loss: 6.7908
# Epoch 94/100
# 4/4 [==============================] - 0s 95ms/step - loss: 4.0006 - val_loss: 6.7033
# Epoch 95/100
# 4/4 [==============================] - 0s 99ms/step - loss: 3.9775 - val_loss: 6.6223
# Epoch 96/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.9563 - val_loss: 6.5472
# Epoch 97/100
# 4/4 [==============================] - 0s 110ms/step - loss: 3.9366 - val_loss: 6.4775
# Epoch 98/100
# 4/4 [==============================] - 0s 110ms/step - loss: 3.9182 - val_loss: 6.4127
# Epoch 99/100
# 4/4 [==============================] - 0s 112ms/step - loss: 3.9009 - val_loss: 6.3523
# Epoch 100/100
# 4/4 [==============================] - 0s 106ms/step - loss: 3.8843 - val_loss: 6.2959

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 0s 15ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : 1.81978

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 3s 355ms/step - loss: 65.1709 - val_loss: 82.2934
# Epoch 2/50
# 4/4 [==============================] - 1s 123ms/step - loss: 56.5234 - val_loss: 72.7345
# Epoch 3/50
# 4/4 [==============================] - 1s 121ms/step - loss: 48.7600 - val_loss: 64.0279
# Epoch 4/50
# 4/4 [==============================] - 1s 133ms/step - loss: 41.8167 - val_loss: 56.2296
# Epoch 5/50
# 4/4 [==============================] - 1s 133ms/step - loss: 35.3132 - val_loss: 48.2151
# Epoch 6/50
# 4/4 [==============================] - 1s 130ms/step - loss: 29.1140 - val_loss: 40.3756
# Epoch 7/50
# 4/4 [==============================] - 1s 153ms/step - loss: 23.2617 - val_loss: 32.7451
# Epoch 8/50
# 4/4 [==============================] - 1s 126ms/step - loss: 18.0020 - val_loss: 25.5728
# Epoch 9/50
# 4/4 [==============================] - 1s 133ms/step - loss: 13.5289 - val_loss: 19.0408
# Epoch 10/50
# 4/4 [==============================] - 1s 154ms/step - loss: 9.9333 - val_loss: 13.1868
# Epoch 11/50
# 4/4 [==============================] - 1s 137ms/step - loss: 7.1850 - val_loss: 8.4892
# Epoch 12/50
# 4/4 [==============================] - 1s 137ms/step - loss: 5.2824 - val_loss: 5.0899
# Epoch 13/50
# 4/4 [==============================] - 1s 133ms/step - loss: 4.3058 - val_loss: 2.9313
# Epoch 14/50
# 4/4 [==============================] - 1s 136ms/step - loss: 4.0569 - val_loss: 1.7780
# Epoch 15/50
# 4/4 [==============================] - 1s 155ms/step - loss: 4.1601 - val_loss: 1.2951
# Epoch 16/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.2781 - val_loss: 1.2201
# Epoch 17/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.2768 - val_loss: 1.4044
# Epoch 18/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.1908 - val_loss: 1.7577
# Epoch 19/50
# 4/4 [==============================] - 1s 136ms/step - loss: 4.0990 - val_loss: 2.1903
# Epoch 20/50
# 4/4 [==============================] - 1s 132ms/step - loss: 4.0468 - val_loss: 2.6052
# Epoch 21/50
# 4/4 [==============================] - 1s 129ms/step - loss: 4.0336 - val_loss: 2.9223
# Epoch 22/50
# 4/4 [==============================] - 1s 127ms/step - loss: 4.0371 - val_loss: 3.1010
# Epoch 23/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.0367 - val_loss: 3.1438
# Epoch 24/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.0249 - val_loss: 3.0838
# Epoch 25/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.0044 - val_loss: 2.9654
# Epoch 26/50
# 4/4 [==============================] - 1s 142ms/step - loss: 3.9817 - val_loss: 2.8322
# Epoch 27/50
# 4/4 [==============================] - 0s 115ms/step - loss: 3.9617 - val_loss: 2.7169
# Epoch 28/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.9453 - val_loss: 2.6355
# Epoch 29/50
# 4/4 [==============================] - 0s 117ms/step - loss: 3.9306 - val_loss: 2.5911
# Epoch 30/50
# 4/4 [==============================] - 1s 143ms/step - loss: 3.9155 - val_loss: 2.5770
# Epoch 31/50
# 4/4 [==============================] - 1s 133ms/step - loss: 3.8991 - val_loss: 2.5953
# Epoch 32/50
# 4/4 [==============================] - 1s 145ms/step - loss: 3.8825 - val_loss: 2.6379
# Epoch 33/50
# 4/4 [==============================] - 1s 152ms/step - loss: 3.8650 - val_loss: 2.6626
# Epoch 34/50
# 4/4 [==============================] - 1s 135ms/step - loss: 3.8473 - val_loss: 2.6790
# Epoch 35/50
# 4/4 [==============================] - 1s 141ms/step - loss: 3.8280 - val_loss: 2.6612
# Epoch 36/50
# 4/4 [==============================] - 1s 152ms/step - loss: 3.8074 - val_loss: 2.6251
# Epoch 37/50
# 4/4 [==============================] - 1s 137ms/step - loss: 3.7862 - val_loss: 2.5864
# Epoch 38/50
# 4/4 [==============================] - 1s 134ms/step - loss: 3.7647 - val_loss: 2.5545
# Epoch 39/50
# 4/4 [==============================] - 1s 150ms/step - loss: 3.7431 - val_loss: 2.5316
# Epoch 40/50
# 4/4 [==============================] - 1s 133ms/step - loss: 3.7210 - val_loss: 2.5135
# Epoch 41/50
# 4/4 [==============================] - 1s 128ms/step - loss: 3.6983 - val_loss: 2.4907
# Epoch 42/50
# 4/4 [==============================] - 1s 120ms/step - loss: 3.6748 - val_loss: 2.4571
# Epoch 43/50
# 4/4 [==============================] - 0s 120ms/step - loss: 3.6506 - val_loss: 2.4116
# Epoch 44/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.6261 - val_loss: 2.3564
# Epoch 45/50
# 4/4 [==============================] - 0s 119ms/step - loss: 3.6017 - val_loss: 2.2952
# Epoch 46/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.5777 - val_loss: 2.2342
# Epoch 47/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.5543 - val_loss: 2.1804
# Epoch 48/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.5315 - val_loss: 2.1368
# Epoch 49/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.5090 - val_loss: 2.1008
# Epoch 50/50
# 4/4 [==============================] - 0s 118ms/step - loss: 3.4865 - val_loss: 2.0653

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")
# Out:
# 1/1 [==============================] - 0s 449ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

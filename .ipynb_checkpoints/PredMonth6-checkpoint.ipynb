# %% [markdown]
# # Example Prediction Temperature Working on 6th Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Month6.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1209, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.089323  0.716889 -1.568319 -0.181191  0.953828  1.462841  12.573619
# 1   0.069323  0.396888 -4.138319 -0.081191  0.433828  1.532841  17.513619
# 2   0.249323  1.136888 -5.098319  0.328809  1.453828  0.732841  15.953619
# 3   0.089323 -0.623112 -2.118319  0.068809 -0.576172  0.122841   5.703619
# 4  -0.050677  1.576888 -4.888319  0.278809  1.973828  0.552841  13.953619

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (967, 7), jeu d'évaluation : (242, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s
100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.4318 - val_loss: nan
# Epoch 70/100
# 4/4 [==============================] - 0s 113ms/step - loss: 3.3631 - val_loss: nan
# Epoch 71/100
# 4/4 [==============================] - 0s 105ms/step - loss: 3.2979 - val_loss: nan
# Epoch 72/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.2355 - val_loss: nan
# Epoch 73/100
# 4/4 [==============================] - 0s 101ms/step - loss: 3.1756 - val_loss: nan
# Epoch 74/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.1179 - val_loss: nan
# Epoch 75/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.0621 - val_loss: nan
# Epoch 76/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.0078 - val_loss: nan
# Epoch 77/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.9548 - val_loss: nan
# Epoch 78/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.9028 - val_loss: nan
# Epoch 79/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.8514 - val_loss: nan
# Epoch 80/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.8004 - val_loss: nan
# Epoch 81/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.7496 - val_loss: nan
# Epoch 82/100
# 4/4 [==============================] - 0s 110ms/step - loss: 2.6989 - val_loss: nan
# Epoch 83/100
# 4/4 [==============================] - 0s 110ms/step - loss: 2.6482 - val_loss: nan
# Epoch 84/100
# 4/4 [==============================] - 0s 106ms/step - loss: 2.5976 - val_loss: nan
# Epoch 85/100
# 4/4 [==============================] - 0s 101ms/step - loss: 2.5474 - val_loss: nan
# Epoch 86/100
# 4/4 [==============================] - 0s 106ms/step - loss: 2.4976 - val_loss: nan
# Epoch 87/100
# 4/4 [==============================] - 0s 102ms/step - loss: 2.4488 - val_loss: nan
# Epoch 88/100
# 4/4 [==============================] - 0s 111ms/step - loss: 2.4016 - val_loss: nan
# Epoch 89/100
# 4/4 [==============================] - 0s 103ms/step - loss: 2.3567 - val_loss: nan
# Epoch 90/100
# 4/4 [==============================] - 0s 108ms/step - loss: 2.3145 - val_loss: nan
# Epoch 91/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.2748 - val_loss: nan
# Epoch 92/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.2369 - val_loss: nan
# Epoch 93/100
# 4/4 [==============================] - 0s 94ms/step - loss: 2.2003 - val_loss: nan
# Epoch 94/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.1640 - val_loss: nan
# Epoch 95/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.1281 - val_loss: nan
# Epoch 96/100
# 4/4 [==============================] - 0s 116ms/step - loss: 2.0927 - val_loss: nan
# Epoch 97/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.0579 - val_loss: nan
# Epoch 98/100
# 4/4 [==============================] - 0s 112ms/step - loss: 2.0239 - val_loss: nan
# Epoch 99/100
# 4/4 [==============================] - 1s 129ms/step - loss: 1.9906 - val_loss: nan
# Epoch 100/100
# 4/4 [==============================] - 0s 117ms/step - loss: 1.9580 - val_loss: nan

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 15ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : 0.77913

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 3s 283ms/step - loss: 12.4475 - val_loss: 1.2723
# Epoch 2/50
# 4/4 [==============================] - 1s 120ms/step - loss: 10.8421 - val_loss: 1.1911
# Epoch 3/50
# 4/4 [==============================] - 0s 118ms/step - loss: 9.6604 - val_loss: 1.1778
# Epoch 4/50
# 4/4 [==============================] - 1s 125ms/step - loss: 8.7938 - val_loss: 1.2506
# Epoch 5/50
# 4/4 [==============================] - 1s 133ms/step - loss: 8.1450 - val_loss: 1.3577
# Epoch 6/50
# 4/4 [==============================] - 1s 140ms/step - loss: 7.6473 - val_loss: 1.4825
# Epoch 7/50
# 4/4 [==============================] - 1s 135ms/step - loss: 7.2561 - val_loss: 1.6235
# Epoch 8/50
# 4/4 [==============================] - 1s 130ms/step - loss: 6.9499 - val_loss: 1.7728
# Epoch 9/50
# 4/4 [==============================] - 1s 128ms/step - loss: 6.7091 - val_loss: 1.9247
# Epoch 10/50
# 4/4 [==============================] - 1s 123ms/step - loss: 6.5238 - val_loss: 2.0710
# Epoch 11/50
# 4/4 [==============================] - 1s 119ms/step - loss: 6.3817 - val_loss: 2.1919
# Epoch 12/50
# 4/4 [==============================] - 1s 118ms/step - loss: 6.2694 - val_loss: 2.2777
# Epoch 13/50
# 4/4 [==============================] - 1s 123ms/step - loss: 6.1717 - val_loss: 2.3318
# Epoch 14/50
# 4/4 [==============================] - 1s 122ms/step - loss: 6.0783 - val_loss: 2.3621
# Epoch 15/50
# 4/4 [==============================] - 1s 128ms/step - loss: 5.9811 - val_loss: 2.3712
# Epoch 16/50
# 4/4 [==============================] - 0s 122ms/step - loss: 5.8788 - val_loss: 2.3524
# Epoch 17/50
# 4/4 [==============================] - 1s 123ms/step - loss: 5.7751 - val_loss: 2.3142
# Epoch 18/50
# 4/4 [==============================] - 1s 126ms/step - loss: 5.6762 - val_loss: 2.2678
# Epoch 19/50
# 4/4 [==============================] - 1s 122ms/step - loss: 5.5857 - val_loss: 2.2428
# Epoch 20/50
# 4/4 [==============================] - 1s 123ms/step - loss: 5.5040 - val_loss: 2.2383
# Epoch 21/50
# 4/4 [==============================] - 1s 127ms/step - loss: 5.4296 - val_loss: 2.2337
# Epoch 22/50
# 4/4 [==============================] - 1s 123ms/step - loss: 5.3619 - val_loss: 2.2439
# Epoch 23/50
# 4/4 [==============================] - 0s 120ms/step - loss: 5.3010 - val_loss: 2.2596
# Epoch 24/50
# 4/4 [==============================] - 0s 115ms/step - loss: 5.2454 - val_loss: 2.2689
# Epoch 25/50
# 4/4 [==============================] - 0s 119ms/step - loss: 5.1943 - val_loss: 2.2655
# Epoch 26/50
# 4/4 [==============================] - 1s 124ms/step - loss: 5.1459 - val_loss: 2.2590
# Epoch 27/50
# 4/4 [==============================] - 0s 114ms/step - loss: 5.0995 - val_loss: 2.2378
# Epoch 28/50
# 4/4 [==============================] - 0s 120ms/step - loss: 5.0550 - val_loss: 2.2109
# Epoch 29/50
# 4/4 [==============================] - 0s 116ms/step - loss: 5.0121 - val_loss: 2.1829
# Epoch 30/50
# 4/4 [==============================] - 0s 123ms/step - loss: 4.9711 - val_loss: 2.1571
# Epoch 31/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.9321 - val_loss: 2.1365
# Epoch 32/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.8953 - val_loss: 2.1220
# Epoch 33/50
# 4/4 [==============================] - 0s 116ms/step - loss: 4.8599 - val_loss: 2.1167
# Epoch 34/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.8254 - val_loss: 2.1181
# Epoch 35/50
# 4/4 [==============================] - 1s 134ms/step - loss: 4.7925 - val_loss: 2.1220
# Epoch 36/50
# 4/4 [==============================] - 1s 133ms/step - loss: 4.7610 - val_loss: 2.1292
# Epoch 37/50
# 4/4 [==============================] - 1s 134ms/step - loss: 4.7310 - val_loss: 2.1307
# Epoch 38/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.7026 - val_loss: 2.1290
# Epoch 39/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.6746 - val_loss: 2.1258
# Epoch 40/50
# 4/4 [==============================] - 0s 116ms/step - loss: 4.6474 - val_loss: 2.1199
# Epoch 41/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.6214 - val_loss: 2.1099
# Epoch 42/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.5968 - val_loss: 2.0972
# Epoch 43/50
# 4/4 [==============================] - 0s 120ms/step - loss: 4.5732 - val_loss: 2.0841
# Epoch 44/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.5506 - val_loss: 2.0708
# Epoch 45/50
# 4/4 [==============================] - 1s 119ms/step - loss: 4.5287 - val_loss: 2.0566
# Epoch 46/50
# 4/4 [==============================] - 0s 115ms/step - loss: 4.5071 - val_loss: 2.0391
# Epoch 47/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.4859 - val_loss: 2.0179
# Epoch 48/50
# 4/4 [==============================] - 0s 119ms/step - loss: 4.4647 - val_loss: 1.9951
# Epoch 49/50
# 4/4 [==============================] - 0s 114ms/step - loss: 4.4440 - val_loss: 1.9735
# Epoch 50/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.4239 - val_loss: 1.9532

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")
# Out:
# 1/1 [==============================] - 0s 426ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

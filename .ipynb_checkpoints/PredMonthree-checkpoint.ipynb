# %% [markdown]
# # Example Prediction Temperature Working on First Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Monththre.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1209, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.029323  0.656888  6.501681  0.738809  0.693828  1.402841 -16.926381
# 1   0.059323 -0.013111  7.821681  0.278809 -0.226172  4.522841  10.453619
# 2   0.039323 -0.813111  7.821681  0.338809 -1.246172  4.822841  12.453619
# 3   0.179323  0.216889  7.931681  0.608809  0.223828  3.302841  -3.046381
# 4   0.059323 -0.813111  8.841681 -0.051191 -1.026172  4.272841   3.453619

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (967, 7), jeu d'évaluation : (242, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s
100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.9412 - val_loss: 3.2736
# Epoch 70/100
# 4/4 [==============================] - 0s 99ms/step - loss: 3.8767 - val_loss: 3.2188
# Epoch 71/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.8108 - val_loss: 3.1589
# Epoch 72/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.7425 - val_loss: 3.0922
# Epoch 73/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.6693 - val_loss: 3.0218
# Epoch 74/100
# 4/4 [==============================] - 0s 101ms/step - loss: 3.5916 - val_loss: 2.9505
# Epoch 75/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.5102 - val_loss: 2.8844
# Epoch 76/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.4258 - val_loss: 2.8226
# Epoch 77/100
# 4/4 [==============================] - 0s 105ms/step - loss: 3.3417 - val_loss: 2.7638
# Epoch 78/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.2608 - val_loss: 2.7076
# Epoch 79/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.1849 - val_loss: 2.6536
# Epoch 80/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.1151 - val_loss: 2.6033
# Epoch 81/100
# 4/4 [==============================] - 0s 100ms/step - loss: 3.0510 - val_loss: 2.5554
# Epoch 82/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.9923 - val_loss: 2.5095
# Epoch 83/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.9382 - val_loss: 2.4655
# Epoch 84/100
# 4/4 [==============================] - 0s 98ms/step - loss: 2.8877 - val_loss: 2.4234
# Epoch 85/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.8403 - val_loss: 2.3834
# Epoch 86/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.7952 - val_loss: 2.3456
# Epoch 87/100
# 4/4 [==============================] - 0s 106ms/step - loss: 2.7524 - val_loss: 2.3101
# Epoch 88/100
# 4/4 [==============================] - 0s 111ms/step - loss: 2.7115 - val_loss: 2.2766
# Epoch 89/100
# 4/4 [==============================] - 0s 110ms/step - loss: 2.6727 - val_loss: 2.2448
# Epoch 90/100
# 4/4 [==============================] - 0s 110ms/step - loss: 2.6360 - val_loss: 2.2148
# Epoch 91/100
# 4/4 [==============================] - 0s 100ms/step - loss: 2.6014 - val_loss: 2.1864
# Epoch 92/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.5688 - val_loss: 2.1599
# Epoch 93/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.5380 - val_loss: 2.1352
# Epoch 94/100
# 4/4 [==============================] - 0s 94ms/step - loss: 2.5089 - val_loss: 2.1122
# Epoch 95/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.4814 - val_loss: 2.0908
# Epoch 96/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.4553 - val_loss: 2.0708
# Epoch 97/100
# 4/4 [==============================] - 0s 94ms/step - loss: 2.4302 - val_loss: 2.0521
# Epoch 98/100
# 4/4 [==============================] - 0s 99ms/step - loss: 2.4062 - val_loss: 2.0346
# Epoch 99/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.3831 - val_loss: 2.0182
# Epoch 100/100
# 4/4 [==============================] - 0s 95ms/step - loss: 2.3607 - val_loss: 2.0029

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 13ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : 1.11924

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 4s 352ms/step - loss: 33.0179 - val_loss: 39.6434
# Epoch 2/50
# 4/4 [==============================] - 1s 129ms/step - loss: 29.3343 - val_loss: 36.7133
# Epoch 3/50
# 4/4 [==============================] - 1s 134ms/step - loss: 26.0505 - val_loss: 34.0449
# Epoch 4/50
# 4/4 [==============================] - 1s 132ms/step - loss: 23.0970 - val_loss: 31.6332
# Epoch 5/50
# 4/4 [==============================] - 1s 129ms/step - loss: 20.3930 - val_loss: 29.0538
# Epoch 6/50
# 4/4 [==============================] - 1s 129ms/step - loss: 17.8952 - val_loss: 26.5198
# Epoch 7/50
# 4/4 [==============================] - 1s 128ms/step - loss: 15.5731 - val_loss: 24.0543
# Epoch 8/50
# 4/4 [==============================] - 1s 126ms/step - loss: 13.4166 - val_loss: 21.7148
# Epoch 9/50
# 4/4 [==============================] - 1s 132ms/step - loss: 11.4375 - val_loss: 19.5193
# Epoch 10/50
# 4/4 [==============================] - 1s 123ms/step - loss: 9.6652 - val_loss: 17.0930
# Epoch 11/50
# 4/4 [==============================] - 1s 123ms/step - loss: 8.1402 - val_loss: 14.6179
# Epoch 12/50
# 4/4 [==============================] - 0s 118ms/step - loss: 6.9302 - val_loss: 11.6397
# Epoch 13/50
# 4/4 [==============================] - 1s 123ms/step - loss: 6.0953 - val_loss: 8.7444
# Epoch 14/50
# 4/4 [==============================] - 1s 137ms/step - loss: 5.6411 - val_loss: 6.4698
# Epoch 15/50
# 4/4 [==============================] - 1s 124ms/step - loss: 5.4808 - val_loss: 4.8823
# Epoch 16/50
# 4/4 [==============================] - 1s 132ms/step - loss: 5.4670 - val_loss: 3.9173
# Epoch 17/50
# 4/4 [==============================] - 0s 118ms/step - loss: 5.4652 - val_loss: 3.4186
# Epoch 18/50
# 4/4 [==============================] - 1s 139ms/step - loss: 5.4177 - val_loss: 3.2276
# Epoch 19/50
# 4/4 [==============================] - 1s 139ms/step - loss: 5.3342 - val_loss: 3.2235
# Epoch 20/50
# 4/4 [==============================] - 1s 147ms/step - loss: 5.2481 - val_loss: 3.3129
# Epoch 21/50
# 4/4 [==============================] - 1s 150ms/step - loss: 5.1806 - val_loss: 3.4230
# Epoch 22/50
# 4/4 [==============================] - 1s 125ms/step - loss: 5.1332 - val_loss: 3.5039
# Epoch 23/50
# 4/4 [==============================] - 0s 117ms/step - loss: 5.0963 - val_loss: 3.5299
# Epoch 24/50
# 4/4 [==============================] - 1s 125ms/step - loss: 5.0611 - val_loss: 3.4979
# Epoch 25/50
# 4/4 [==============================] - 1s 121ms/step - loss: 5.0229 - val_loss: 3.4209
# Epoch 26/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.9820 - val_loss: 3.3196
# Epoch 27/50
# 4/4 [==============================] - 1s 117ms/step - loss: 4.9403 - val_loss: 3.2146
# Epoch 28/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.8995 - val_loss: 3.1222
# Epoch 29/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.8599 - val_loss: 3.0508
# Epoch 30/50
# 4/4 [==============================] - 1s 137ms/step - loss: 4.8212 - val_loss: 3.0012
# Epoch 31/50
# 4/4 [==============================] - 1s 129ms/step - loss: 4.7834 - val_loss: 2.9673
# Epoch 32/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.7466 - val_loss: 2.9397
# Epoch 33/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.7113 - val_loss: 2.9095
# Epoch 34/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.6777 - val_loss: 2.8698
# Epoch 35/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.6457 - val_loss: 2.8190
# Epoch 36/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.6154 - val_loss: 2.7594
# Epoch 37/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.5863 - val_loss: 2.6978
# Epoch 38/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.5589 - val_loss: 2.6412
# Epoch 39/50
# 4/4 [==============================] - 1s 144ms/step - loss: 4.5331 - val_loss: 2.5931
# Epoch 40/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.5085 - val_loss: 2.5547
# Epoch 41/50
# 4/4 [==============================] - 1s 129ms/step - loss: 4.4845 - val_loss: 2.5244
# Epoch 42/50
# 4/4 [==============================] - 1s 130ms/step - loss: 4.4613 - val_loss: 2.4995
# Epoch 43/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.4392 - val_loss: 2.4764
# Epoch 44/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.4174 - val_loss: 2.4537
# Epoch 45/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.3962 - val_loss: 2.4305
# Epoch 46/50
# 4/4 [==============================] - 1s 142ms/step - loss: 4.3755 - val_loss: 2.4064
# Epoch 47/50
# 4/4 [==============================] - 1s 130ms/step - loss: 4.3553 - val_loss: 2.3798
# Epoch 48/50
# 4/4 [==============================] - 1s 135ms/step - loss: 4.3354 - val_loss: 2.3504
# Epoch 49/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.3157 - val_loss: 2.3198
# Epoch 50/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.2966 - val_loss: 2.2893

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")
# Out:
# 1/1 [==============================] - 0s 461ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

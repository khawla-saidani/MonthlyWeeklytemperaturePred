# %% [markdown]
# # Example Prediction Temperature Working on First Month To Predict The temperature of Weekly Nasa Dataset

# %%
import pandas as pd
data = pd.read_csv('Month4.csv')
data.columns
# Out:
# Index(['ALLSKY_KT', 'WS2M', 'T2M', 'PS', 'WS10M', 'QV2M', 'RH2M'], dtype='object')

# %%
data.shape
# Out:
# (1170, 7)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
corrMatrix = data.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
data.head(5)
# Out:
#    ALLSKY_KT      WS2M       T2M        PS     WS10M      QV2M       RH2M
# 0   0.039323 -1.093112  0.571681  0.968809 -1.716172  2.812841  12.883619
# 1  -0.030677  1.676889  1.941681  0.868809  2.093828  2.012841   5.203619
# 2  -0.000677  1.056888  1.121681  0.718809  1.203828  1.832841   7.203619
# 3   0.009323  1.106888  2.481681  0.538809  1.433828 -0.427159 -14.676381
# 4   0.039323  0.366889  3.871681  0.628809  0.463828  0.182841 -15.296381

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la vont
ax3 = fig.add_subplot(223)
plt.plot(data['WS2M'])
ax3.title.set_text('Wind speed 10M')
# Évolution du déficit de himidité de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['RH2M'])
ax4.title.set_text('Humidity')
# Evolution de radation
#ax5 = fig.add_subplot(225)
#plt.plot(data['Radiation'])
#ax5.title.set_text('Radation')

plt.show()

# %%
split_fraction = 0.80
split_idx = int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (936, 7), jeu d'évaluation : (234, 7)

# %% [markdown]
# ### Train The NN and obtimise with descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib as plt

# %%
# Création du jeu d'entraînement
sampling_rate = 1 # Fréquence d'échantillonnage
sequence_length = 120  # Longueur de la séquence
batch_size = 256 # Taille de batch

# Création du jeu d'entraînement: contient Temperature, Pressure, Humidity, WindSpeed, day length
X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_train = tf.data.Dataset.zip((X_train, y_train))
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,1,3,4,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 2],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# # Training The RNN To Predict Third Month

# %%
# from tensorflow import keras

dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 6)]          0
#
#  gru (GRU)                   (None, 120, 6)            252
#
#  dense (Dense)               (None, 120, 6)            42
#
#  dense_1 (Dense)             (None, 120, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s
100
# 4/4 [==============================] - 0s 110ms/step - loss: 0.7141 - val_loss: 0.7482
# Epoch 100/100
# 4/4 [==============================] - 1s 121ms/step - loss: 0.6913 - val_loss: 0.7200

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Temperature prédite")
    plt.plot(true_data, ".-", label="Vraie Temperature")
    plt.legend()
    plt.xlabel("Pas de temps")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 11ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : 0.59413

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 120
future_step = 1

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 256
step_size = 1 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_1 (GRU)                 (None, 32)                3936
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 3s 137ms/step - loss: 6.2556
# Epoch 2/50
# 4/4 [==============================] - 1s 118ms/step - loss: 5.6886
# Epoch 3/50
# 4/4 [==============================] - 1s 116ms/step - loss: 5.3375
# Epoch 4/50
# 4/4 [==============================] - 1s 133ms/step - loss: 5.1464
# Epoch 5/50
# 4/4 [==============================] - 1s 120ms/step - loss: 5.0610
# Epoch 6/50
# 4/4 [==============================] - 1s 125ms/step - loss: 5.0226
# Epoch 7/50
# 4/4 [==============================] - 1s 119ms/step - loss: 4.9889
# Epoch 8/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.9515
# Epoch 9/50
# 4/4 [==============================] - 1s 131ms/step - loss: 4.9189
# Epoch 10/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.8963
# Epoch 11/50
# 4/4 [==============================] - 1s 125ms/step - loss: 4.8807
# Epoch 12/50
# 4/4 [==============================] - 1s 125ms/step - loss: 4.8668
# Epoch 13/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.8510
# Epoch 14/50
# 4/4 [==============================] - 1s 151ms/step - loss: 4.8322
# Epoch 15/50
# 4/4 [==============================] - 1s 140ms/step - loss: 4.8121
# Epoch 16/50
# 4/4 [==============================] - 1s 148ms/step - loss: 4.7919
# Epoch 17/50
# 4/4 [==============================] - 1s 140ms/step - loss: 4.7728
# Epoch 18/50
# 4/4 [==============================] - 1s 144ms/step - loss: 4.7547
# Epoch 19/50
# 4/4 [==============================] - 1s 117ms/step - loss: 4.7380
# Epoch 20/50
# 4/4 [==============================] - 1s 117ms/step - loss: 4.7227
# Epoch 21/50
# 4/4 [==============================] - 1s 126ms/step - loss: 4.7078
# Epoch 22/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.6929
# Epoch 23/50
# 4/4 [==============================] - 0s 113ms/step - loss: 4.6772
# Epoch 24/50
# 4/4 [==============================] - 0s 118ms/step - loss: 4.6608
# Epoch 25/50
# 4/4 [==============================] - 1s 127ms/step - loss: 4.6440
# Epoch 26/50
# 4/4 [==============================] - 1s 116ms/step - loss: 4.6275
# Epoch 27/50
# 4/4 [==============================] - 1s 124ms/step - loss: 4.6111
# Epoch 28/50
# 4/4 [==============================] - 1s 123ms/step - loss: 4.5942
# Epoch 29/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.5768
# Epoch 30/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.5591
# Epoch 31/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.5406
# Epoch 32/50
# 4/4 [==============================] - 1s 118ms/step - loss: 4.5220
# Epoch 33/50
# 4/4 [==============================] - 0s 117ms/step - loss: 4.5035
# Epoch 34/50
# 4/4 [==============================] - 1s 122ms/step - loss: 4.4843
# Epoch 35/50
# 4/4 [==============================] - 0s 112ms/step - loss: 4.4646
# Epoch 36/50
# 4/4 [==============================] - 1s 120ms/step - loss: 4.4443
# Epoch 37/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.4238
# Epoch 38/50
# 4/4 [==============================] - 0s 113ms/step - loss: 4.4028
# Epoch 39/50
# 4/4 [==============================] - 1s 130ms/step - loss: 4.3817
# Epoch 40/50
# 4/4 [==============================] - 1s 121ms/step - loss: 4.3600
# Epoch 41/50
# 4/4 [==============================] - 1s 115ms/step - loss: 4.3381
# Epoch 42/50
# 4/4 [==============================] - 0s 110ms/step - loss: 4.3159
# Epoch 43/50
# 4/4 [==============================] - 1s 139ms/step - loss: 4.2932
# Epoch 44/50
# 4/4 [==============================] - 1s 136ms/step - loss: 4.2696
# Epoch 45/50
# 4/4 [==============================] - 1s 137ms/step - loss: 4.2453
# Epoch 46/50
# 4/4 [==============================] - 1s 128ms/step - loss: 4.2207
# Epoch 47/50
# 4/4 [==============================] - 0s 111ms/step - loss: 4.1960
# Epoch 48/50
# 4/4 [==============================] - 0s 110ms/step - loss: 4.1709
# Epoch 49/50
# 4/4 [==============================] - 1s 114ms/step - loss: 4.1457
# Epoch 50/50
# 4/4 [==============================] - 0s 121ms/step - loss: 4.1202

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Temperature")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie Temperature")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la Temperature")

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
